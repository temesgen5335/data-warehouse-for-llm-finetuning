# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
print(matplotlib.__version__)
# Out:
# 3.9.0

# %%
#   urlopen is a function that allows you to open URLs
#BeautifulSoup is a Python library used for web scraping purposes to pull the data out of HTML and XML files.

from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
#url  = "https://www.scrapehero.com/web-scraping-using-playwright-in-python-and-javascript/"

#url = "https://www.ethiobookreview.com/book/ye-ethiopia-tarik-ke-lusi-arat-million"
url = "https://am.wikipedia.org/wiki/%E1%8A%A0%E1%8B%B2%E1%88%B5_%E1%8B%98%E1%88%98%E1%8A%95_(%E1%8C%8B%E1%8B%9C%E1%8C%A3)"

html = urlopen(url)

# %%
#The second argument 'lxml' is the html parser 
import lxml

#soup = BeautifulSoup(html, 'lxml')
soup = BeautifulSoup(html, 'html.parser')
soup = soup.prettify()
type(soup)
# Out:
# str

# %%
#bs4.BeautifulSoup
from bs4 import BeautifulSoup

# Get the title
title = soup.title
print(title)
# Out:
# <built-in method title of str object at 0xb3acf0>

# %%
#text = soup.get_text()

# Access the entire parsed HTML content as a string
text = soup.text

# Print the complete text content
print(text)
# Out:
# ውክፔዲያ - የኢትዮጵያ ኦርቶዶክስ ተዋሕዶ ቤተ ክርስቲያን
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		የማውጫ ቁልፎች
#
#
#
# ዋና ገጽየተመደበ ማውጫበቅርብ ጊዜ የተለወጡማናቸውንም ለማየትእርዳታምንጭጌወቅታዊ ጉዳዮች (ዜና)መዋጮ ለመስጠት
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ፍለጋ
#
#
#
#
#
#
#
#
#
#
#
# ፍለጋ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# የብዕር ስም ለማውጣት
#
# ለመግባት
#
#
#
#
#
#
#
#
# የኔ መሣርያዎች
#
#
#
#
#
#  የብዕር ስም ለማውጣት ለመግባት
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# Contributionsውይይት ለዚሁ ቁ. አድራሻ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# Beginning
#
#
#
#
#
# 1በታሪክ
#
#
#
# Toggle በታሪክ subsection
#
#
#
#
#
# 1.1መሠረቶች
#
#
#
#
#
#
#
# 1.2መካከለኛ ዘመን
#
#
#
#
#
#
#
#
#
# 2ከሌሎቹ የምትለይበት
#
#
#
# Toggle ከሌሎቹ የምትለይበት subsection
#
#
#
#
#
# 2.1የምትቀበላቸው ቅዱሳን መጻሕፍት
#
#
#
#
#
#
#
# 2.2ልሳነ ቅዳሴና ልሳነ ስብከት
#
#
#
#
#
#
#
# 2.3ሥነ ሕንፃ
#
#
#
#
#
#
#
# 2.4ታቦት
#
#
# ...

# %%
#You can use the find_all() method of soup to extract useful html tags within a webpage
soup.find_all('a')
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/%E1%8B%8B%E1%8A%93%E1%8B%8D_%E1%8C%88%E1%8C%BD" title="ዋናውን ገጽ ተመልከት [z]"><span>ዋና ገጽ</span></a>,
#  <a href="/wiki/%E1%88%8D%E1%8B%A9:CategoryTree"><span>የተመደበ ማውጫ</span></a>,
#  <a accesskey="r" href="/wiki/%E1%88%8D%E1%8B%A9:RecentChanges" title="በዚሁ ዊኪ ላይ በቅርቡ የተደረጉ ለውጦች [r]"><span>በቅርብ ጊዜ የተለወጡ</span></a>,
#  <a accesskey="x" href="/wiki/%E1%88%8D%E1%8B%A9:Random" title="ወደ ማንኛውም ገጽ በነሲብ ለመሔድ [x]"><span>ማናቸውንም ለማየት</span></a>,
#  <a href="/wiki/%E1%8A%A5%E1%88%AD%E1%8B%B3%E1%89%B3:%E1%8A%A5%E1%88%AD%E1%8B%B3%E1%89%B3" title="ረድኤት ለማግኘት"><span>እርዳታ</span></a>,
#  <a href="/wiki/%E1%8B%8D%E1%8A%AD%E1%8D%94%E1%8B%B2%E1%8B%AB_%E1%8B%8D%E1%8B%AD%E1%8B%AD%E1%89%B5:%E1%88%9D%E1%8A%95%E1%8C%AD%E1%8C%8C" title="ስለ መርሃገብሩ አጠቃቀም አለመረዳት"><span>ምንጭጌ</span></a>,
# ...

# %%
#You can use the find_all() method of soup to extract useful html tags within a webpage. 

soup.find_all("p")
# Out:
# [<p><b>አዲስ ዘመን</b> ጋዜጣ <a class="new" href="/w/index.php?title=%E1%8B%A8%E1%8A%A2%E1%89%B5%E1%8B%AE%E1%8C%B5%E1%8B%AB_%E1%8D%95%E1%88%AC%E1%88%B5_%E1%8B%B5%E1%88%AD%E1%8C%85%E1%89%B5&amp;action=edit&amp;redlink=1" title="የኢትዮጵያ ፕሬስ ድርጅት (ገጹ ገና አልተጻፈም)">የኢትዮጵያ ፕሬስ ድርጅት</a> ሥር የምተዳደር ነዉ ፣ በየዕለቱ የሚታተም ብሔራዊ <a class="new" href="/w/index.php?title=%E1%8C%8B%E1%8B%9C%E1%8C%A3&amp;action=edit&amp;redlink=1" title="ጋዜጣ (ገጹ ገና አልተጻፈም)">ጋዜጣ</a> ነው። አዲስ ዘመን በአሁኑ ጊዜ ከ ፵ በላይ ጋዜጠኞች ያሉት ሲሆን የጋዜጣው  መጠን ‘መካከለኛ’ /በርሊነር/ (31.5 cm × 47 cm (12.4 in × 18.5 in) ) ሆኖ የፊትና ጀርባ ገፆችን በሙሉ  ቀለም  ያቀርባል። ይህ ጋዜጣ የአገሪቱ ብቸኛው ዕለታዊ ጋዜጣ ሲሆን የመንግሥትን አቋም የሚያንፀባርቅ እና በየዕለቱ የተለያዩ ልማታዊ ዜናዎችን ይዞ ይወጣል።
#  </p>,
# ...

# %%
# Print the first 10 rows for sanity check
bodys = soup.find_all('body')
print(bodys[:5])
# Out:
# [<body class="skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-አዲስ_ዘመን_ጋዜጣ rootpage-አዲስ_ዘመን_ጋዜጣ skin-vector-2022 action-view"><a class="mw-jump-link" href="#bodyContent">Jump to content</a>
# <div class="vector-header-container">
# <header class="vector-header mw-header">
# <div class="vector-header-start">
# <nav aria-label="Site" class="vector-main-menu-landmark" role="navigation">
# <div class="vector-dropdown vector-main-menu-dropdown vector-button-flush-left vector-button-flush-right" id="vector-main-menu-dropdown">
# <input aria-haspopup="true" aria-label="Main menu" class="vector-dropdown-checkbox" data-event-name="ui.dropdown-vector-main-menu-dropdown" id="vector-main-menu-dropdown-checkbox" role="button" type="checkbox"/>
# ...

# %%
#use a for loop to filter out wanted attributes only

paragraphs = soup.find_all("p")

#for link in all_links:
#    print(link.get("href"))

print(paragraphs)
# Out:
# [<p><b>አዲስ ዘመን</b> ጋዜጣ <a class="new" href="/w/index.php?title=%E1%8B%A8%E1%8A%A2%E1%89%B5%E1%8B%AE%E1%8C%B5%E1%8B%AB_%E1%8D%95%E1%88%AC%E1%88%B5_%E1%8B%B5%E1%88%AD%E1%8C%85%E1%89%B5&amp;action=edit&amp;redlink=1" title="የኢትዮጵያ ፕሬስ ድርጅት (ገጹ ገና አልተጻፈም)">የኢትዮጵያ ፕሬስ ድርጅት</a> ሥር የምተዳደር ነዉ ፣ በየዕለቱ የሚታተም ብሔራዊ <a class="new" href="/w/index.php?title=%E1%8C%8B%E1%8B%9C%E1%8C%A3&amp;action=edit&amp;redlink=1" title="ጋዜጣ (ገጹ ገና አልተጻፈም)">ጋዜጣ</a> ነው። አዲስ ዘመን በአሁኑ ጊዜ ከ ፵ በላይ ጋዜጠኞች ያሉት ሲሆን የጋዜጣው  መጠን ‘መካከለኛ’ /በርሊነር/ (31.5 cm × 47 cm (12.4 in × 18.5 in) ) ሆኖ የፊትና ጀርባ ገፆችን በሙሉ  ቀለም  ያቀርባል። ይህ ጋዜጣ የአገሪቱ ብቸኛው ዕለታዊ ጋዜጣ ሲሆን የመንግሥትን አቋም የሚያንፀባርቅ እና በየዕለቱ የተለያዩ ልማታዊ ዜናዎችን ይዞ ይወጣል።
# ...

# %% [markdown]
# Using Selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# Set up Selenium webdriver for Firefox
driver = webdriver.Firefox()
url = "https://www.ethiobookreview.com/book/ye-ethiopia-tarik-ke-lusi-arat-million"
driver.get(url)
time.sleep(3)  # Let the page load

# Use BeautifulSoup to parse the page source
soup = BeautifulSoup(driver.page_source, 'html.parser')

# Find the element containing the text data
text_data_element = soup.find('div', class_='et_pb_module et_pb_text et_pb_text_1 et_pb_bg_layout_light')

if text_data_element:
    # Extract text data
    text_data = text_data_element.get_text()
    print(text_data)
else:
    print("Text data element not found")

# Close the Selenium webdriver
driver.quit()

# %%
import requests
from bs4 import BeautifulSoup

url = "https://am.wikipedia.org/wiki/%E1%8B%A8%E1%8A%A2%E1%89%B5%E1%8B%AE%E1%8C%B5%E1%8B%AB_%E1%8A%A6%E1%88%AD%E1%89%B6%E1%8B%B6%E1%8A%AD%E1%88%B5_%E1%89%B0%E1%8B%8B%E1%88%95%E1%8B%B6_%E1%89%A4%E1%89%B0_%E1%8A%AD%E1%88%AD%E1%88%B5%E1%89%B2%E1%8B%AB%E1%8A%95"

# Fetch the HTML content
response = requests.get(url)
content = response.content

# Parse the HTML content
soup = BeautifulSoup(content, "html.parser")


# Extract text from paragraphs (adjust selector as needed)
paragraphs = soup.find_all("p")
all_text = []
for paragraph in paragraphs:
    all_text.append(paragraph.get_text(strip=True))
print(all_text)
# Out:
# ['የኢትዮጵያ ኦርቶዶክስ ተዋሕዶ ቤተ ኃይማኖት ተከታዮች በተለይምየኢትዮጵያ ኦርቶዶክስ ተዋሕዶ ቤተክርስቲያን፣ ኢየሱስ ክርስቶስ በ፴ ዓ/ም በፈለገ ዮርዳኖስ በመጥምቁ ዮሐንስ እጅ በዮርዳኖስ ባሕር የተጠመቀበትን ዕለት የሚያስታውሰው፣ ኤጲፋንያ በመባልም የሚታወቀው ደማቅ በዓል ነው። መገለጥ፣ መታየት ማለት ነው። የኢየሱስ ክርስቶስ ጥምቀት ታሪክ የሚገኘው በማቴዎስ ወንጌል ምዕራፍ ፫ ቁ ፲፫–፲፯ ውስጥ ነው።   ጌታ', 'በአገራችን፣ ጥር ፲ ቀን፣ በከተራ፣ በገጠር ወራጅ ውሃ የሚከተርበት፣ ታቦታት ከየአቢያተ ክርስቲያናቱ በዓሉ ወደሚከበርበት ቦታ በምዕመናን ታጅበው በዝማሬና በሆታ ይሄዳሉ። እዚያም በተዘጋጀአቡነ ባስልዮስከእስክንድርያ ፓትርያርክአቡነ ዮሳብ 2ኛየጵጵስና ማዕረግ ተቀበሉ። ኢትዮጵያም፤ ከዚያን ጊዜ ጀምሮ እራሷን የቻለች ሆነች። ወደ ፶፭-፷ ሚሊዮን የሚቀርቡ ምእመናን ሲኖሩት ከምሥራቃዊ ኦርቶዶክስ አብያተ ክርስቲያናት ሁሉ ትልቁ ነው።', '«ተዋሕዶ» ከልሣነ ግእዝየመነጨ ቃል ሲሆን፣ ትርጒሙም "አንድ ሆኖ" ማለት ነው። ከእመቤታችን ከቅድስት ድንግል ማርያም ከሥጋዋ ሥጋ ከነፍሷ ነፍስ ነስቶ በተዋሕዶ ከበረ ማለት ነው። ለዚሁም በዐረብኛተመሳሳይ ቃል "ታውሒድ" ሲባል፣ በአንድ አምላክ ብቻ ማመን የሚለውን ፅንሰ ኣሳብ ያመለክታል። በኦርቶዶክስ ተዋሕዶ አብያተ ክርስቲያናትቃሉ የሚነካ የክርስቶስ ባሕርይ በ"ሰብዓዊ" እና በ"መለኮታዊ" ተለይቶ ሳይሆን አንድ ብቻ እንደሆነ የሚለው ጽኑ እምነት ነው።', 'በ443ዓ.ም. (451 እ.ኤ.አ.) በሮማው ንጉሥ መርቅያን ዘመነ መንግሥት ፮፻፶ ኤጲስ ቆጶሳት በተገኙበት የተሰበሰበው የኬልቄዶን ጉባኤከሮማው ሊቀ ጳጳሳትቀዳማዊ ልዮን"ክርስቶስ ሁለት የተለያዩ ባሕርያት አሉት" የሚል ጽሑፍ አቅርቦላቸው ነበር። ዳሩ ግን የእስክን
# ...
